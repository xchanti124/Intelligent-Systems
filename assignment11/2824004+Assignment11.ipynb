# %% [markdown]
# # Intelligent Systems 2023: Practical Assignment 11
#
# ## Machine Learning Agents
#
# Your name: Chantal Ariu
#
# Your VUnetID: car103
#
# If you do not provide your name and VUnetID we will not accept your submission.
#
# ### Preliminaries
#
# At the end of this exercise you should be able to work with some basic Machine Learning concepts, and implement and evaluate a learning-based approach to playing Schnapsen. In this notebook we are going to create an adaptive bot. We will use the principle discussed in the machine learning lecture, but now in an agent setting. This comes down to using basic hill-climbing search, but learn the heuristic function rather than implementing it. This will require a few basic ingredients.
#
# Feature vectors were discussed in the lecture. Didn't get it, or working ahead? See
# https://brilliant.org/wiki/feature-vector/
# https://www.youtube.com/watch?v=3Vy47dbI708
#
# ### Practicalities
#
# Follow this Notebook step-by-step. For this course it is necessary that you manipulate the python programmes we provide. You can do the exercises in any Programming Editor of your liking. Still, please fill in the questions in this notebook as usual. You can also run tournaments in it if you want, but running them in your editor or via the commandline seems much more convenient.
#
# Please use your studentID+Assignment6.ipynb as the name of the Notebook, and fill in the missing cells.
#
# Note: unlike the courses dedicated to programming we will not evaluate the style of the programs. But we will, however, test your programs on other data that we provide, and your program should give the correct output to the test-data as well.
#
# As was mentioned, the assignment is graded as pass/fail. To pass you need to have either a full working code or an explanation of what you tried and what didn't work for the tasks that you were unable to complete (you can use multi-line comments or a text cell).
#
# ## Initialising
#
# First, we have to install the schnapsen python package.
# Run the below code cell.
# After running the cell, you have the schnapsen Github repository cloned in your current directory.
# You can find the new directory created with the name `schnapsen`.
# The detailed installation instructions can be found in the [README.md](https://github.com/intelligent-systems-course/schnapsen) of the repo.

# %%
# If you are on a UNIX system (Linux or Mac OS)
# !python3 -m pip uninstall schnapsen -y && rm -rf schnapsen && git clone https://github.com/intelligent-systems-course/schnapsen && cd schnapsen && python3 -m pip install -e . && cd ..
# Out:
# Found existing installation: schnapsen 0.0.3
# Uninstalling schnapsen-0.0.3:
#   Successfully uninstalled schnapsen-0.0.3
# Cloning into 'schnapsen'...
# remote: Enumerating objects: 1735, done.
# remote: Counting objects: 100% (822/822), done.
# remote: Compressing objects: 100% (233/233), done.
# remote: Total 1735 (delta 608), reused 666 (delta 561), pack-reused 913
# Receiving objects: 100% (1735/1735), 2.16 MiB | 2.54 MiB/s, done.
# Resolving deltas: 100% (971/971), done.
# Obtaining file:///Users/chantalariu/Documents/Uni/Year%201/P2/Intelligent%20Systems/Assignments/assignment11/schnapsen
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: class-resolver>=0.0.10 in /Users/chantalariu/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from schnapsen==0.0.3) (0.4.2)
# Requirement already satisfied: click==8.1.3 in /Users/chantalariu/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from schnapsen==0.0.3) (8.1.3)
# Requirement already satisfied: scikit-learn==1.3.2 in /Users/chantalariu/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from schnapsen==0.0.3) (1.3.2)
# Requirement already satisfied: joblib==1.3.2 in /Users/chantalariu/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from schnapsen==0.0.3) (1.3.2)
# Requirement already satisfied: flask==2.3.3 in /Users/chantalariu/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from schnapsen==0.0.3) (2.3.3)
# Requirement already satisfied: Werkzeug==3.0.1 in /Users/chantalariu/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from schnapsen==0.0.3) (3.0.1)
# Requirement already satisfied: Jinja2>=3.1.2 in /Users/chantalariu/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from flask==2.3.3->schnapsen==0.0.3) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.1.2 in /Users/chantalariu/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from flask==2.3.3->schnapsen==0.0.3) (2.1.2)
# Requirement already satisfied: blinker>=1.6.2 in /Users/chantalariu/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from flask==2.3.3->schnapsen==0.0.3) (1.7.0)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in /Users/chantalariu/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from scikit-learn==1.3.2->schnapsen==0.0.3) (1.26.2)
# Requirement already satisfied: scipy>=1.5.0 in /Users/chantalariu/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from scikit-learn==1.3.2->schnapsen==0.0.3) (1.11.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/chantalariu/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from scikit-learn==1.3.2->schnapsen==0.0.3) (3.2.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/chantalariu/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from Werkzeug==3.0.1->schnapsen==0.0.3) (2.1.3)
# Building wheels for collected packages: schnapsen
#   Building editable for schnapsen (pyproject.toml) ... done
#   Created wheel for schnapsen: filename=schnapsen-0.0.3-0.editable-py3-none-any.whl size=16259 sha256=207f6007101ccf97f3965d07fd7edbdaa2fc53dd38039df2a7def5a8e04bf743
#   Stored in directory: /private/var/folders/p9/3vhw02td3qzcsm583w1m4mgw0000gn/T/pip-ephem-wheel-cache-nkppyxcw/wheels/80/a3/db/5a7a6d15bb47dc0748e460646772bb1a680725c264b453700b
# Successfully built schnapsen
# Installing collected packages: schnapsen
# Successfully installed schnapsen-0.0.3

# %%
# If you are on Windows
# !pip uninstall schnapsen -y rd /s /q schnapsen && git clone https://github.com/intelligent-systems-course/schnapsen && cd schnapsen && pip install -e . && cd ..

# %% [markdown]
# ## (Supervised) machine learning
#
# So far, we've been trying to come up with bots that rely on heuristics and search
# algorithms, e.g., Minimax, Monte-Carlo Tree Search, etc. This assignment, instead, will
# focus on learning-based methods, where the agent, given a state, learns what moves
# (actions) lead to winning. You might have heard of [AlphaGo](https://en.wikipedia.org/wiki/AlphaGo),
# which actually combines both a Monte Carlo tree search algorithm and machine learning.
# Schnapsen is no different from the game of Go, except that it's state / aciton spaces are
# much smaller, and also it involves an imperfect information phase.
#
# Typically for these kinds of board games, reinforcement learning (RL), which is a branch of
# machine learning is used. However, RL is out of scope for this assignment. Therefore,
# we will do something untypical. We'll use supervised learning (SL), instead of RL.
#
# This will still give you a glimpse of machine learning, and hopefully in the future,
# you'll understand why RL is more suitable for this kind of task, and come up with your
# own RL algorithm to solve it.
#
# SL typicall includes three big steps:
#
# 1. Collect data.
# 2. Train a ML model with the collected data.
# 3. Run and evaluate the trained model.
#
# All the functions and classes we need are included in [`ml_bot.py`](./ml_bot.py).
# Let's go through them one by one.

# %% [markdown]
# ### 1. Collect data
#
# We'll collect supervised data, meaning that every $x$ has its label $y$.
#
# For example, if $x$ is an image of a dog, then $y$ is 0, and if $x$ is an image of a cat,
# then $y$ is 1.
#
# In our case, $x$ is what the agent sees + the moves that the leader and the follower take,
# and $y$ is 0 if this move resulted in losing, and 1 if it resulted in winning.
#
# It's easy for us to express "what the agent sees + the moves that the leader and the follower take" in human langauge, but this is not easy for the machine to understand. Therefore, we'll
# have to convert it to numbers, e.g., 0's and 1's, so that it can understand.

# %% [markdown]
# #### Task 1:
#
# The function `def create_state_and_actions_vector_representation()` in [`ml_bot.py`](./ml_bot.py)
# does this job. This function takes three arguments, `perspective`, `leader_move`, and `follower_move`, and return them as a vector of numbers so that the machine can understand.
#
# The three variables `player_game_state_representation`, `leader_move_representation`, and `follower_move_representation` are marked with `???`. You have to call the necessary
# functions with the correct arguments to get the correct values (features) for them.
#
# Write them down in the below cell.

# %%
MyCode1 = """
    player_game_state_representation = get_state_feature_vector(perspective)
    leader_move_representation = get_move_feature_vector(leader_move)
    follower_move_representation = get_move_feature_vector(follower_move)
"""

# %% [markdown]
# #### Task 2
#
# Now that the function `def create_state_and_actions_vector_representation()` is ready to use,
# we will collect data by calling the function `def create_replay_memory_dataset()`.
#
# Simply running the below cell won't work, since this function takes two arguments:
# `bot1` and `bot2`.
# Try to understand the function by looking at the docstring, and run the function by
# specifying the bots.
# You can provide the function with any bots, but let us start with `RandBot`.
# Go to our previous assignments on how to instantiate the `Bot` objects.
#
# Write your code in `MyCode2`.

# %%
import random
from schnapsen.bots import RandBot, RdeepBot
from ml_bot import create_replay_memory_dataset

bot1 = RandBot(random.Random(42), "RandBot")
bot2 = RandBot(random.Random(42), "RandBot")
# RdeepBot(5, 5, random.Random(42), "RdeepBot")

create_replay_memory_dataset(bot1=bot1, bot2=bot2)
# Out:
# Progress: 500/10000
# Progress: 1000/10000
# Progress: 1500/10000
# Progress: 2000/10000
# Progress: 2500/10000
# Progress: 3000/10000
# Progress: 3500/10000
# Progress: 4000/10000
# Progress: 4500/10000
# Progress: 5000/10000
# Progress: 5500/10000
# Progress: 6000/10000
# Progress: 6500/10000
# Progress: 7000/10000
# Progress: 7500/10000
# Progress: 8000/10000
# Progress: 8500/10000
# Progress: 9000/10000
# Progress: 9500/10000
# Progress: 10000/10000
# Replay memory dataset recorder for 10000 games.
# Dataset is stored at: ML_replay_memories/random_random_10k_games.txt

# %%
MyCode2 = """
bot1 = RandBot(random.Random(42), "RandBot")
bot2 = RandBot(random.Random(42), "RandBot")
"""

# %% [markdown]
# Now the offline data is collected, and saved at `./ML_replay_memories/random_random_10k_games.txt`
#
# #### Task 3
#
# Let's see what it looks like. Every row is a pair of $(x^{(i)}, y^{(i)})$, where
# $x^{(i)}$ is "what the agent sees + the moves that the leader and the follower take",
# and $y^{(i)}$ is a label. Often we also call $x^{(i)}$ as a feature and $y^{(i)}$ as
# a target.
#
# As you can see now they are now all numbers so that the machine can understand, but
# perhaps not so easy for you as a human, since the feature extraction (converting to
# numeric values) is done by us, not by you. But you can go through the code and try to
# understand how these feature extractions were done. In the below cell, (1) explain what
# the numbers before and after `||`, and (2) what these numbers mean.

# %%
MyReport1 = """
(1) The explanation on what the numbers before and after || mean can be found in the function 'notify_game_end'. On the
right side of the ||, there is either only one 0 or 1, indicating whether the game was lost (0) or won(1). On the left
side of the ||, all the information about the game state is stored in the form of a vector (since the function 'create_state_and_actions_vector_representation')
is called. 

"""

# %% [markdown]
# ### 2. Train a ML model with the collected data.
#
# Now we will train a ML model! Our model $f_{\bm{\theta}}(x) = \hat{y}$ is a function that
# maps $x$ to $\hat{y}$, where $\bm{\theta}$ are learanble parameters. As all of our target
# values, i.e., $y$ are categorical values, we will treat this as a classification problem,
# rather than a regression problem. There are a numerous machine learning models we can use
# for a classification problem, but in our assignment, we will only try two and compare
# them.

# %% [markdown]
# #### Task 4.
#
# The below cell will run training, but you have to give it an argument first. Look at
# the code and (1) explain what arguments does it take? (2) What are the differences
# between the arguments?

# %%
from ml_bot import train_model

train_model("NN")
# Out:
# Dataset Statistics:
# Samples of wins: 150844
# Samples of losses: 150844
# Training a Complex (Neural Network) model.
# Starting training phase...
# Iteration 1, loss = 0.59950348
# Validation score: 0.684179
# Iteration 2, loss = 0.58372711
# Validation score: 0.693858
# Iteration 3, loss = 0.57554561
# Validation score: 0.701349
# Iteration 4, loss = 0.56960564
# Validation score: 0.704896
# Iteration 5, loss = 0.56558405
# Validation score: 0.707813
# Iteration 6, loss = 0.56294697
# Validation score: 0.708906
# Iteration 7, loss = 0.56098113
# Validation score: 0.710464
# Iteration 8, loss = 0.55941896
# Validation score: 0.711591
# Iteration 9, loss = 0.55790533
# Validation score: 0.711459
# Iteration 10, loss = 0.55645898
# Validation score: 0.713315
# Iteration 11, loss = 0.55509623
# Validation score: 0.714541
# Iteration 12, loss = 0.55358674
# Validation score: 0.715105
# Iteration 13, loss = 0.55215094
# Validation score: 0.715138
# Iteration 14, loss = 0.55076076
# Validation score: 0.716497
# Iteration 15, loss = 0.54926557
# Validation score: 0.717425
# Iteration 16, loss = 0.54780603
# Validation score: 0.718718
# Iteration 17, loss = 0.54619096
# Validation score: 0.719779
# Iteration 18, loss = 0.54453680
# Validation score: 0.720243
# Iteration 19, loss = 0.54277053
# Validation score: 0.722198
# Iteration 20, loss = 0.54090872
# Validation score: 0.723524
# Iteration 21, loss = 0.53879924
# Validation score: 0.725679
# Iteration 22, loss = 0.53658008
# Validation score: 0.727502
# Iteration 23, loss = 0.53423214
# Validation score: 0.728828
# Iteration 24, loss = 0.53179625
# Validation score: 0.730187
# Iteration 25, loss = 0.52936595
# Validation score: 0.732805
# Iteration 26, loss = 0.52681640
# Validation score: 0.734131
# Iteration 27, loss = 0.52424947
# Validation score: 0.735357
# Iteration 28, loss = 0.52166209
# Validation score: 0.736750
# Iteration 29, loss = 0.51903450
# Validation score: 0.739302
# Iteration 30, loss = 0.51653726
# Validation score: 0.741258
# Iteration 31, loss = 0.51400539
# Validation score: 0.741523
# Iteration 32, loss = 0.51159520
# Validation score: 0.743147
# Iteration 33, loss = 0.50923938
# Validation score: 0.744141
# Iteration 34, loss = 0.50702124
# Validation score: 0.745103
# Iteration 35, loss = 0.50485638
# Validation score: 0.746660
# Iteration 36, loss = 0.50282705
# Validation score: 0.747224
# Iteration 37, loss = 0.50074851
# Validation score: 0.748881
# Iteration 38, loss = 0.49880394
# Validation score: 0.749677
# Iteration 39, loss = 0.49701473
# Validation score: 0.752594
# Iteration 40, loss = 0.49525989
# Validation score: 0.753853
# Iteration 41, loss = 0.49364994
# Validation score: 0.755710
# Iteration 42, loss = 0.49201321
# Validation score: 0.754417
# Iteration 43, loss = 0.49048030
# Validation score: 0.755743
# Iteration 44, loss = 0.48913225
# Validation score: 0.756638
# Iteration 45, loss = 0.48776339
# Validation score: 0.756936
# Iteration 46, loss = 0.48646194
# Validation score: 0.758162
# Iteration 47, loss = 0.48529223
# Validation score: 0.758958
# Iteration 48, loss = 0.48406382
# Validation score: 0.760052
# Iteration 49, loss = 0.48299390
# Validation score: 0.761013
# Iteration 50, loss = 0.48187578
# Validation score: 0.762041
# Iteration 51, loss = 0.48082487
# Validation score: 0.762306
# Iteration 52, loss = 0.47981726
# Validation score: 0.763002
# Iteration 53, loss = 0.47895612
# Validation score: 0.762836
# Iteration 54, loss = 0.47813824
# Validation score: 0.762969
# Iteration 55, loss = 0.47715842
# Validation score: 0.764692
# Iteration 56, loss = 0.47637408
# Validation score: 0.762935
# Iteration 57, loss = 0.47546607
# Validation score: 0.763201
# Iteration 58, loss = 0.47476202
# Validation score: 0.765156
# Iteration 59, loss = 0.47404057
# Validation score: 0.765587
# Iteration 60, loss = 0.47337084
# Validation score: 0.765123
# Iteration 61, loss = 0.47270343
# Validation score: 0.765819
# Iteration 62, loss = 0.47208735
# Validation score: 0.766913
# Iteration 63, loss = 0.47135573
# Validation score: 0.766880
# Iteration 64, loss = 0.47083731
# Validation score: 0.766383
# Iteration 65, loss = 0.47027281
# Validation score: 0.767675
# Iteration 66, loss = 0.46964816
# Validation score: 0.766847
# Iteration 67, loss = 0.46927224
# Validation score: 0.766714
# Iteration 68, loss = 0.46868529
# Validation score: 0.767443
# Iteration 69, loss = 0.46820752
# Validation score: 0.767974
# Iteration 70, loss = 0.46772058
# Validation score: 0.766946
# Iteration 71, loss = 0.46720218
# Validation score: 0.769134
# Iteration 72, loss = 0.46690998
# Validation score: 0.768438
# Iteration 73, loss = 0.46642286
# Validation score: 0.768604
# Iteration 74, loss = 0.46600963
# Validation score: 0.768338
# Iteration 75, loss = 0.46554970
# Validation score: 0.769200
# Iteration 76, loss = 0.46524949
# Validation score: 0.768405
# Iteration 77, loss = 0.46482729
# Validation score: 0.768106
# Iteration 78, loss = 0.46447508
# Validation score: 0.770493
# Iteration 79, loss = 0.46415638
# Validation score: 0.769333
# Iteration 80, loss = 0.46376250
# Validation score: 0.769001
# Iteration 81, loss = 0.46348170
# Validation score: 0.769863
# Iteration 82, loss = 0.46310096
# Validation score: 0.769598
# Iteration 83, loss = 0.46283839
# Validation score: 0.770659
# Iteration 84, loss = 0.46252428
# Validation score: 0.769333
# Iteration 85, loss = 0.46217168
# Validation score: 0.769333
# Iteration 86, loss = 0.46191969
# Validation score: 0.770161
# Iteration 87, loss = 0.46167014
# Validation score: 0.770062
# Iteration 88, loss = 0.46125850
# Validation score: 0.771288
# Iteration 89, loss = 0.46099812
# Validation score: 0.770261
# Iteration 90, loss = 0.46072271
# Validation score: 0.769797
# Iteration 91, loss = 0.46053969
# Validation score: 0.769631
# Iteration 92, loss = 0.46026289
# Validation score: 0.771222
# Iteration 93, loss = 0.45998029
# Validation score: 0.770327
# Iteration 94, loss = 0.45972807
# Validation score: 0.772449
# Iteration 95, loss = 0.45952028
# Validation score: 0.771355
# Iteration 96, loss = 0.45930354
# Validation score: 0.771686
# Iteration 97, loss = 0.45903108
# Validation score: 0.772349
# Iteration 98, loss = 0.45874860
# Validation score: 0.773012
# Iteration 99, loss = 0.45853754
# Validation score: 0.771587
# Iteration 100, loss = 0.45833820
# Validation score: 0.771918
# Iteration 101, loss = 0.45815467
# Validation score: 0.771984
# Iteration 102, loss = 0.45782757
# Validation score: 0.772382
# Iteration 103, loss = 0.45766953
# Validation score: 0.772217
# Iteration 104, loss = 0.45748161
# Validation score: 0.771984
# Iteration 105, loss = 0.45735302
# Validation score: 0.774106
# Iteration 106, loss = 0.45708090
# Validation score: 0.772415
# Iteration 107, loss = 0.45691193
# Validation score: 0.772581
# Iteration 108, loss = 0.45675110
# Validation score: 0.772913
# Iteration 109, loss = 0.45657980
# Validation score: 0.773178
# Iteration 110, loss = 0.45625342
# Validation score: 0.773178
# Iteration 111, loss = 0.45620778
# Validation score: 0.774073
# Iteration 112, loss = 0.45593446
# Validation score: 0.773443
# Validation score did not improve more than tol=0.000100 for 6 consecutive epochs. Stopping.
# The model was trained in  1.6257709821065267 minutes.

# %%
MyReport2 = """
(1) The train_model function takes as argument the model type, which can be 'NN' for neural network or "LR' for logistic 
regression. 
(2) The main difference is that choosing NN will train the model like a neural-network, whereas choosing LR will train a
logistic regression model. Neural network models are usually complexer and more powerful than logistic regression models.
"""

# %% [markdown]
# ### 3. Run and evaluate the trained model.
#
# #### Task 5
#
# Now your model, depending on what argument you gave above, is trained and saved at
# `./ML_models/simple_model`. It's time for us to load this model, and put this on a test.
# We'll first let our ML model play against a RandBot.
#
# The below cell is not complete. The class `MLPlayingBot` and `RandBot` takes arguments,
# and they are not given. Specify the arguments, and copy the code in `MyCode3`

# %%
import pathlib
import random

from schnapsen.game import SchnapsenGamePlayEngine
from schnapsen.bots import RandBot

from ml_bot import MLPlayingBot

engine = SchnapsenGamePlayEngine()
model_dir = "ML_models"
model_name = "simple_model"
model_location = pathlib.Path(model_dir) / model_name

bot1 = MLPlayingBot(model_location=model_location, name="MLBot")
bot2 = RandBot(random.Random(42), name="RandBot")

winner_id, game_points, score = engine.play_game(bot1, bot2, random.Random(0))
print(f"Game ended. Winner is {winner_id} with {game_points} points and {score}")
# Out:
# Game ended. Winner is MLBot with 1 points and Score(direct_points=76, pending_points=0)

# %%
MyCode3 = """
bot1 = MLPlayingBot(model_location=model_location, name="MLBot")
bot2 = RandBot(random.Random(42), name="RandBot")
"""

# %% [markdown]
# #### Task 6
#
# The above cell only runs one game MLBot vs. RandBot. As you have learned already, since
# there is always randomness involved, we should play this game multiple times and compare
# the results. In the below cell, write code for a round-robin tournament where $N$ bots
# play against each other. One of them has to be an MLBot, and the other $N-1$ can be any
# bots that you have learend in this course. $N$ should be higher than 2. You can use
# the code from the previous assignments.

# %%
myrepeats = 4

# Create bots.
bot1 = MLPlayingBot(model_location=model_location, name="MLBot")
bot2 = RandBot(rand=random.Random(42), name="randbot")
bot3 = RdeepBot(5, 5, rand=random.Random(44), name="rdeepbot")

bots = [bot1, bot2, bot3]

n = len(bots)
wins = {str(bot): 0 for bot in bots}
matches = [(p1, p2) for p1 in range(n) for p2 in range(n) if p1 < p2]

totalgames = (n * n - n) / 2 * myrepeats
playedgames = 0

print("Playing {} games:".format(int(totalgames)))
for a, b in matches:
    for r in range(myrepeats):
        if random.choice([True, False]):
            p = [a, b]
        else:
            p = [b, a]

        winner_id, game_points, score = engine.play_game(
            bots[p[0]], bots[p[1]], random.Random(45)
        )

        wins[str(winner_id)] += game_points

        playedgames += 1
        print(
            "Played {} out of {:.0f} games ({:.0f}%): {} \r".format(
                playedgames, totalgames, playedgames / float(totalgames) * 100, wins
            )
        )
# Out:
# Playing 12 games:
# Played 1 out of 12 games (8%): {'MLBot': 3, 'randbot': 0, 'rdeepbot': 0}
# Played 2 out of 12 games (17%): {'MLBot': 5, 'randbot': 0, 'rdeepbot': 0}
# Played 3 out of 12 games (25%): {'MLBot': 8, 'randbot': 0, 'rdeepbot': 0}
# Played 4 out of 12 games (33%): {'MLBot': 11, 'randbot': 0, 'rdeepbot': 0}
# Played 5 out of 12 games (42%): {'MLBot': 11, 'randbot': 0, 'rdeepbot': 3}
# Played 6 out of 12 games (50%): {'MLBot': 12, 'randbot': 0, 'rdeepbot': 3}
# Played 7 out of 12 games (58%): {'MLBot': 12, 'randbot': 0, 'rdeepbot': 5}
# Played 8 out of 12 games (67%): {'MLBot': 14, 'randbot': 0, 'rdeepbot': 5}
# Played 9 out of 12 games (75%): {'MLBot': 14, 'randbot': 0, 'rdeepbot': 8}
# Played 10 out of 12 games (83%): {'MLBot': 14, 'randbot': 0, 'rdeepbot': 11}
# Played 11 out of 12 games (92%): {'MLBot': 14, 'randbot': 0, 'rdeepbot': 12}
# Played 12 out of 12 games (100%): {'MLBot': 14, 'randbot': 0, 'rdeepbot': 14}

# %%
MyCode4 = """
(From Assignment 4)
myrepeats = 4

# Create bots.
bot1 = MLPlayingBot(model_location=model_location, name="MLBot")
bot2 = RandBot(rand=random.Random(42), name="randbot")
bot3 = RdeepBot(5, 5, rand=random.Random(44), name="rdeepbot")

bots = [bot1, bot2, bot3]

n = len(bots)
wins = {str(bot): 0 for bot in bots}
matches = [(p1, p2) for p1 in range(n) for p2 in range(n) if p1 < p2]

totalgames = (n * n - n) / 2 * myrepeats
playedgames = 0

print("Playing {} games:".format(int(totalgames)))
for a, b in matches:
    for r in range(myrepeats):
        if random.choice([True, False]):
            p = [a, b]
        else:
            p = [b, a]

        winner_id, game_points, score = engine.play_game(
            bots[p[0]], bots[p[1]], random.Random(45)
        )

        wins[str(winner_id)] += game_points

        playedgames += 1
        print(
            "Played {} out of {:.0f} games ({:.0f}%): {} \r".format(
                playedgames, totalgames, playedgames / float(totalgames) * 100, wins
            )
        )
"""

# %% [markdown]
# In the below cell, write down the results of your experiment.

# %%
MyReport3 = """
Playing 12 games:
Played 1 out of 12 games (8%): {'MLBot': 3, 'randbot': 0, 'rdeepbot': 0} 
Played 2 out of 12 games (17%): {'MLBot': 5, 'randbot': 0, 'rdeepbot': 0} 
Played 3 out of 12 games (25%): {'MLBot': 8, 'randbot': 0, 'rdeepbot': 0} 
Played 4 out of 12 games (33%): {'MLBot': 11, 'randbot': 0, 'rdeepbot': 0} 
Played 5 out of 12 games (42%): {'MLBot': 11, 'randbot': 0, 'rdeepbot': 3} 
Played 6 out of 12 games (50%): {'MLBot': 12, 'randbot': 0, 'rdeepbot': 3} 
Played 7 out of 12 games (58%): {'MLBot': 12, 'randbot': 0, 'rdeepbot': 5} 
Played 8 out of 12 games (67%): {'MLBot': 14, 'randbot': 0, 'rdeepbot': 5} 
Played 9 out of 12 games (75%): {'MLBot': 14, 'randbot': 0, 'rdeepbot': 8} 
Played 10 out of 12 games (83%): {'MLBot': 14, 'randbot': 0, 'rdeepbot': 11} 
Played 11 out of 12 games (92%): {'MLBot': 14, 'randbot': 0, 'rdeepbot': 12} 
Played 12 out of 12 games (100%): {'MLBot': 14, 'randbot': 0, 'rdeepbot': 14} 
"""

# %% [markdown]
# ## Final Task: Collect all the results
#
# Uncomment and run this cell (and all the cells above) to generate the text file that you have to hand in together with the notebook on canvas!
#
# ### Please hand in only the text file which is generated by this method!

# %%
def exportToText(*args):
    with open(args[0], "w") as f:
        for argument in args:
            f.write("{}\n".format(argument))

exportToText("assignment11.txt", MyCode1, MyCode2, MyReport1, MyReport2, MyCode3, MyCode4, MyReport3)

# %% [markdown]
# Congrats on finishing all the assignments!
#
# Machine learning, especially deep learning, has become a key to solving many difficult
# problems in AI, the past 10 years, ranging from board games, self-driving cars, to
# scientific discoveries.
#
# This assignment only touched upon a small tiny fraction of machine learning and what it
# can do. If you are interested in machine learning, feel free to check out numerous online
# materials and the related VU courses.
#
# Have fun. To be continued in Project Intelligent Systems in Period 3.
